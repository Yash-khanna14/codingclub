# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-khanna14/codingclub/blob/main/UploadImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mping
img=mping.imread('/Capture1.png')
imgplot=plt.imshow(img)
